# %%
        aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaA    %%writefile conf/config.yaml
# Arch	                        Start Lr	Max Steps	Decay Steps
# FullyConnectedArch	        1.00E-03	1500000	        15000	   
# FourierNetArch                1.00E-03	400000	        7500	   
# ModifiedFourierNetArch 	1.00E-03	400000	        7500	   
# SirenArch                     2.00E-05	500000	        5000	   
# DGMArch                       1.00E-03        1500000         15000           

# WARNING: Setting "exact_continuity" to true or setting the arch
# as "ModifiedFourierNetArch" increases the memory requirements of the 
# problem. Batchsizes may need to be reduced for such cases.  

defaults :
  - modulus_default
  - arch:
      - fully_connected
  - scheduler: exponential_lr 
  - optimizer: adam
  - loss: sum
  - _self_

jit: false


training:
  rec_results_freq : 5000
  rec_constraint_freq: 100000
  max_steps : 3000000
# Out:
# Overwriting conf/config.yaml

# %%
# %%writefile fhn3Ppred.py

from modulus.models.fully_connected import FullyConnectedArch
from modulus.models.fourier_net import FourierNetArch
from modulus.models.siren import SirenArch
from modulus.models.modified_fourier_net import ModifiedFourierNetArch
from modulus.models.dgm import DGMArch

from sympy import Symbol, Eq
from sympy import Symbol, Function, Number
from modulus.eq.pde import PDE
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate
import modulus
from modulus.hydra import instantiate_arch, ModulusConfig
from modulus.solver import Solver
from modulus.domain import Domain
from modulus.geometry.primitives_1d import Point1D
from modulus.geometry.primitives_3d import (
    Plane,
    Channel,
    Box,
    Sphere,
    Cylinder,
    Torus,
    Cone,
    TriangularPrism,
    Tetrahedron,
    IsoTriangularPrism,
    ElliCylinder,
)
from modulus.domain.constraint import (
    PointwiseBoundaryConstraint,
    PointwiseInteriorConstraint,
    PointwiseConstraint,
    VariationalConstraint
)
from modulus.domain.validator import PointwiseValidator
from modulus.key import Key
from modulus.node import Node
from modulus.eq.pde import PDE
from modulus.geometry import Parameterization
from sympy import Symbol, Eq, Abs, tanh, Or, And
from modulus.utils.io import (
    csv_to_dict,
    ValidatorPlotter,
    InferencerPlotter,
)
from modulus.solver import SequentialSolver
from modulus.domain.monitor import PointwiseMonitor
from modulus.models.deeponet import DeepONetArch
from modulus.domain.constraint.continuous import DeepONetConstraint
from modulus.models.moving_time_window import MovingTimeWindowArch
from modulus.domain.monitor import Monitor
from modulus.domain.constraint import Constraint
from modulus.graph import Graph
from modulus.key import Key
from modulus.constants import TF_SUMMARY
from modulus.distributed import DistributedManager
from modulus.utils.io import dict_to_csv, csv_to_dict
from modulus.domain.inferencer.pointwise import PointwiseInferencer as PointwiseInferencer
from modulus.loss.loss import CausalLossNorm

  
import os
import time
import numpy as np
import torch
from torch.utils.tensorboard import SummaryWriter
from torch.optim import Optimizer
from torch.optim.lr_scheduler import _LRScheduler
from torch.cuda.amp import GradScaler
import torch.nn as nn
import torch.cuda.profiler as profiler
import torch.distributed as dist
from termcolor import colored, cprint
from copy import copy
from operator import add
from omegaconf import DictConfig, OmegaConf
import hydra
import itertools
from collections import Counter
from typing import Dict, List, Optional
import logging
from contextlib import ExitStack
from typing import List, Union, Tuple, Callable


from modulus.domain.constraint import Constraint
from modulus.domain import Domain
from modulus.loss.aggregator import Sum
from modulus.utils.training.stop_criterion import StopCriterion
from modulus.constants import TF_SUMMARY, JIT_PYTORCH_VERSION
from modulus.hydra import (
    instantiate_optim,
    instantiate_sched,
    instantiate_agg,
    add_hydra_run_path,
)
from modulus.distributed.manager import DistributedManager
from modulus.models.layers import Activation 
    
t_max = 50.0
n_w=1
t_w= t_max/n_w
BTZ=1024

def print_folder_contents(folder_path):
    if not os.path.exists(folder_path):
        print(f"Folder '{folder_path}' does not exist.")
        return

    print(f"Contents of folder '{folder_path}':")
    for item in os.listdir(folder_path):
        print(item)



def generateValidator(i,nodes,data_folder="../.././validation/"):
    # Read data arrays from CSV files
    
    print_folder_contents(data_folder)
    T = np.load(data_folder + "T.npy")
    K = np.load(data_folder + "K.npy")
    U = np.load(data_folder + "U.npy")
    V = np.load(data_folder + "V.npy")
    SOLs = np.load(data_folder + "SOLs.npy")
    SOLw = np.load(data_folder + "SOLw.npy")

    t = np.expand_dims(T, axis=-1)
    k = np.expand_dims(K, axis=-1)
    u = np.expand_dims(U, axis=-1)
    Solx = np.expand_dims(SOLs, axis=-1)
    Solw = np.expand_dims(SOLw, axis=-1)
    v = np.expand_dims(V, axis=-1)

    print("Added validation of shape", np.shape(Solx))
    invar_numpy = {
        "t": t,
        "K": k,
        "V": v,
        "U": u,
    }

    outvar_numpy = {
        "x1": Solx,
        "w":Solw
    }
    validator = PointwiseValidator(
        nodes=nodes, invar=invar_numpy, true_outvar=outvar_numpy, batch_size=1024,plotter=None
    )
    return validator



def generateDataC(i,nodes,data_folder="../.././treino1/"):
    # Read data arrays from CSV files
    
    print_folder_contents(data_folder)

    T = np.load(data_folder + "T.npy")
    K = np.load(data_folder + "K.npy")
    U = np.load(data_folder + "U.npy")
    V = np.load(data_folder + "V.npy")
    SOLs = np.load(data_folder + "SOLs.npy")
    SOLw = np.load(data_folder + "SOLw.npy")

    t = np.expand_dims(T, axis=-1)
    k = np.expand_dims(K, axis=-1)
    u = np.expand_dims(U, axis=-1)
    Solx = np.expand_dims(SOLs, axis=-1)
    Solw = np.expand_dims(SOLw, axis=-1)
    v = np.expand_dims(V, axis=-1)

    invar_numpy = {
        "t": t,
        "K": k,
        "V": v,
        "U": u,
    }
    print("Added data constraint of shape", np.shape(Solx))

    outvar_numpy = {
        "x1": Solx,
        "w":Solw
    }
    constraint = PointwiseConstraint.from_numpy(
        nodes=nodes,
        invar=invar_numpy,
        outvar=outvar_numpy,
        batch_size=5*BTZ,
        num_workers=10,
        shuffle=True,
        

    )

    return constraint


class SpringMass(PDE):
    name = "SpringMass"

    def __init__(self):

        t = Symbol("t")
        K = Symbol("K")
       
        input_variables = {"t": t,"K":K}

        x = Function("x1")(*input_variables)
        w= Function("w")(*input_variables)
        self.equations = {}
        self.equations["ode_x1"] =10*(x*(x-0.4)*(1-x)-w+K) -x.diff(t)
        self.equations["ode_w"]  =0.2*(x*0.2-0.8*w) -w.diff(t)
        
@modulus.main(config_path="conf", config_name="config")
def run(cfg: ModulusConfig) -> None:


    # make list of nodes to unroll graph on
    sm = SpringMass()
    sm.pprint()
    #sm_net = FullyConnectedArch(
    #    input_keys=[Key("t"), Key("K")],
    #    output_keys=[Key("x1")],
    #)
    #nodes = sm.make_nodes() + [
    #    sm_net.make_node(name="network")
    #]


    
    # make list of nodes to unroll graph on
    sm = SpringMass()
    sm.pprint()
    #sm_net = FullyConnectedArch(
    #    input_keys=[Key("t"), Key("K")],
    #    output_keys=[Key("x1")],
    #)
    #nodes = sm.make_nodes() + [
    #    sm_net.make_node(name="network")
    #]
    
        
    flow_net = FullyConnectedArch(
            input_keys=[Key("t"), Key("U"),Key("V"),Key("K") ],
            output_keys=[Key("x1"),Key("w")],
            layer_size=32,
            nr_layers=6,
            activation_fn=Activation.TANH,
        )

    #time_window_net = MovingTimeWindowArch(flow_net, t_w)

    nodes = sm.make_nodes() +[flow_net.make_node(name="network")]

    # make importance model
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    importance_model_graph = Graph(
        nodes,
        invar=[Key("t"), Key("U"),Key("V"),Key("K") ],
        req_names=[
            Key("w", derivatives=[Key("t")]),
            Key("x1", derivatives=[Key("t")]),
            Key("ode_x1")
        ],
    ).to(device)


    
    
    def importance_measure(invar):
        outvar = importance_model_graph(
            Constraint._set_device(invar, device=device, requires_grad=True)
        )
        importance = (
            
            outvar["ode_x1"]** 2
        ) ** 0.5 
        return importance.cpu().detach().numpy()

    
    

    

    t_symbol = Symbol("t")
    k_symbol= Symbol("K")
    v_symbol= Symbol("V")
    u_symbol= Symbol("U")
    
    time_range = {t_symbol: (0,t_w )}
    k_range= {k_symbol:(0.08,0.012)}
    v_range= {v_symbol:(0,0.12)}
    u_range= {u_symbol:(0,1)}

    for node in nodes:
        print(node.__str__())
   
    # add constraints to solver
    # make geometry
    geo = Point1D(0)
    geo2=Box(
            (0,0,0),
            (
               1,  
               1,
               1,
            ),
         )
    

    tr = {t_symbol: (0, t_w)}

    # make domain
        # make initial condition domain
    ic_domain = Domain("initial_conditions")

  
    # initial conditions
    IC = PointwiseBoundaryConstraint(
        nodes=nodes,
        geometry=geo,
        outvar={"x1": u_symbol,"w":v_symbol},
        batch_size=2*BTZ,
        parameterization={**{t_symbol:0},**k_range,**v_range,**u_range},
        lambda_weighting={
            "x1": 100,# + 1000*x_symbol.diff(t_symbol)*x_symbol.diff(t_symbol),
            "w": 100 #+ 1000*x_symbol.diff(t_symbol)*x_symbol.diff(t_symbol)
        },
        importance_measure=importance_measure,

        
        quasirandom=True,
    )

    ic_domain.add_constraint(IC, name="IC")
    
        # solve over given time period
    interior = PointwiseInteriorConstraint(
        nodes=nodes,
        geometry=geo2,
        outvar={"ode_x1": 0.0,"ode_w":0.0},
        batch_size=BTZ,
        parameterization={**tr,**k_range,**v_range,**u_range},
        #criteria=And(t_symbol > 0, t_symbol < 3),
        lambda_weighting={
            "ode_x1": 1,# + 1000*x_symbol.diff(t_symbol)*x_symbol.diff(t_symbol),
            "ode_w":1 #+ 1000*x_symbol.diff(t_symbol)*x_symbol.diff(t_symbol)
        },
        importance_measure=importance_measure,

        quasirandom=True,
    )
    ic_domain.add_constraint(interior, name="interior")
    
            # solve over given time period
    interior = PointwiseInteriorConstraint(
        nodes=nodes,
        geometry=geo2,
        outvar={"ode_x1": 0.0},
        batch_size=BTZ,
        parameterization={**tr,**k_range,**v_range,**u_range},
        #criteria=And(t_symbol > 0, t_symbol < 3),
        lambda_weighting={
            "ode_x1": 1 +  t_symbol
        },
                
        importance_measure=importance_measure,

        quasirandom=True,
    )
    ic_domain.add_constraint(interior, name="interior2")
    

        
        
    data_folder="../.././validation/"
    T = np.load(data_folder + "T.npy")
    K = np.load(data_folder + "K.npy")
    U = np.load(data_folder + "U.npy")
    V = np.load(data_folder + "V.npy")
    SOLs = np.load(data_folder + "SOLs.npy")
    SOLw = np.load(data_folder + "SOLw.npy")

    t = np.expand_dims(T, axis=-1)
    k = np.expand_dims(K, axis=-1)
    u = np.expand_dims(U, axis=-1)
    Solx = np.expand_dims(SOLs, axis=-1)
    Solw = np.expand_dims(SOLw, axis=-1)
    v = np.expand_dims(V, axis=-1)

    print("Added monitor of shape", np.shape(Solx))
    invar_numpy = {
        "t": t,
        "K": k,
        "V": v,
        "U": u,
        "True_u":Solx,
        "True_w":Solw
    }
    

    
    extrapol_val = PointwiseMonitor(
         invar_numpy,
         output_names=["x1", "w"],
         metrics={
          
             "Extra_error_mean": lambda var: torch.mean(
                
                 torch.abs((torch.abs(var["True_u"]) - torch.abs(var["x1"])))
             ),
             
             "Extra_error_max": lambda var: torch.max(
                
                 torch.abs((torch.abs(var["True_u"]) - torch.abs(var["x1"])))
             ),
         },
         nodes=nodes,
     )
    ic_domain.add_monitor(extrapol_val)
 
    
    
    print("Added monitor of shape", np.shape(Solx))

    
    
    data_folder="../.././validation/"
    T = np.load(data_folder + "T.npy")
    K = np.load(data_folder + "K.npy")
    U = np.load(data_folder + "U.npy")
    V = np.load(data_folder + "V.npy")
    SOLs = np.load(data_folder + "SOLs.npy")
    SOLw = np.load(data_folder + "SOLw.npy")

    t = np.expand_dims(T, axis=-1)
    k = np.expand_dims(K, axis=-1)
    u = np.expand_dims(U, axis=-1)
    Solx = np.expand_dims(SOLs, axis=-1)
    Solw = np.expand_dims(SOLw, axis=-1)
    v = np.expand_dims(V, axis=-1)

    print("Added validation of shape", np.shape(Solx))
    invar_numpy = {
        "t": t,
        "K": k,
        "V": v,
        "U": u,
        "True_u":Solx,
        "True_w":Solw
    }
    

    
    interpol_val = PointwiseMonitor(
         invar_numpy,
         output_names=["x1", "w"],
         metrics={
          
             "Inter_error_mean": lambda var: torch.mean(
                
                 torch.abs((torch.abs(var["True_u"]) - torch.abs(var["x1"])))
             ),
             
             "Inter_error_max": lambda var: torch.max(
                
                torch.abs((torch.abs(var["True_u"]) - torch.abs(var["x1"])))
             ),
         },
         nodes=nodes,
     )
    ic_domain.add_monitor(interpol_val)
 
    
    

    
    dom=[]
    dom.append((1,ic_domain))
    print(cfg)
    # make solver
    #slv = Solver(cfg, domain)
    #print(domains)
    i=0
    for a,d in dom:
      #  print(d)
      #  print(d.name)
#        d.add_inferencer(generateValidator(i,nodes))
        d.add_validator(generateValidator(i,nodes))
        d.add_constraint(generateDataC(i,nodes,data_folder="../.././treino1/"),"data1")
        d.add_constraint(generateDataC(i,nodes,data_folder="../.././treino2/"),"data2")
        d.add_constraint(generateDataC(i,nodes,data_folder="../.././treino3/"),"data3")
       

        i=i+1
    
     
    slv = SequentialSolver(
        cfg,
        dom,

    )
    slv.solve()

        
        
        
if __name__ == "__main__":
    run()
# Out:
# Overwriting fhn3Ppred.py

# %%
# !rm -r outputs/fhn3Ppred
# !python fhn3Ppred.py
# Out:
# [01:30:39] - JitManager: {'_enabled': False, '_arch_mode': <JitArchMode.ONLY_ACTIVATION: 1>, '_use_nvfuser': True, '_autograd_nodes': False}
# [01:30:39] - GraphManager: {'_func_arch': False, '_debug': False, '_func_arch_allow_partial_hessian': True}
# ode_x1: 10*K + 10*(1 - x1)*(x1 - 0.4)*x1 - 10*w - x1__t
# ode_w: -0.16*w + 0.04*x1 - w__t
# ode_x1: 10*K + 10*(1 - x1)*(x1 - 0.4)*x1 - 10*w - x1__t
# ode_w: -0.16*w + 0.04*x1 - w__t
# node: Sympy Node: ode_x1
# evaluate: SympyToTorch
# inputs: [K, w, x1]
# derivatives: [x1__t]
# outputs: [ode_x1]
# optimize: False
# node: Sympy Node: ode_w
# evaluate: SympyToTorch
# inputs: [w, x1]
# derivatives: [w__t]
# outputs: [ode_w]
# optimize: False
# node: Arch Node: network
# evaluate: FullyConnectedArch
# inputs: [t, U, V, K]
# derivatives: []
# outputs: [x1, w]
# optimize: True
# Added monitor of shape (1000000, 1)
# Added monitor of shape (1000000, 1)
# Added validation of shape (1000000, 1)
# {'training': {'max_steps': 3000000, 'grad_agg_freq': 1, 'rec_results_freq': 5000, 'rec_validation_freq': '${training.rec_results_freq}', 'rec_inference_freq': '${training.rec_results_freq}', 'rec_monitor_freq': '${training.rec_results_freq}', 'rec_constraint_freq': 100000, 'save_network_freq': 1000, 'print_stats_freq': 100, 'summary_freq': 1000, 'amp': False, 'amp_dtype': 'float16', 'ntk': {'use_ntk': False, 'save_name': None, 'run_freq': 1000}}, 'graph': {'func_arch': False, 'func_arch_allow_partial_hessian': True}, 'stop_criterion': {'metric': None, 'min_delta': None, 'patience': 50000, 'mode': 'min', 'freq': 1000, 'strict': False}, 'profiler': {'profile': False, 'start_step': 0, 'end_step': 100, 'name': 'nvtx'}, 'network_dir': '.', 'initialization_network_dir': '', 'save_filetypes': 'vtk', 'summary_histograms': False, 'jit': False, 'jit_use_nvfuser': True, 'jit_arch_mode': 'only_activation', 'jit_autograd_nodes': False, 'cuda_graphs': True, 'cuda_graph_warmup': 20, 'find_unused_parameters': False, 'broadcast_buffers': False, 'device': '', 'debug': False, 'run_mode': 'train', 'arch': {'fully_connected': {'arch_type': 'fully_connected', 'input_keys': '???', 'output_keys': '???', 'detach_keys': '???', 'scaling': None, 'layer_size': 512, 'nr_layers': 6, 'skip_connections': False, 'activation_fn': 'silu', 'adaptive_activations': False, 'weight_norm': True}}, 'models': '???', 'loss': {'_target_': 'modulus.loss.aggregator.Sum', 'weights': None}, 'optimizer': {'_params_': {'compute_gradients': 'adam_compute_gradients', 'apply_gradients': 'adam_apply_gradients'}, '_target_': 'torch.optim.Adam', 'lr': 0.001, 'betas': [0.9, 0.999], 'eps': 1e-08, 'weight_decay': 0.0, 'amsgrad': False}, 'scheduler': {'_target_': 'torch.optim.lr_scheduler.ExponentialLR', 'gamma': 0.99998718}, 'batch_size': '???', 'custom': '???'}
# Contents of folder '../.././validation/':
# U.npy
# V.npy
# K.npy
# SOLs.npy
# T.npy
# SOLw.npy
# Added validation of shape (1000000, 1)
# Contents of folder '../.././treino1/':
# V.csv
# T.csv
# U.npy
# V.npy
# K.npy
# SOLs.npy
# T.npy
# SOLw.npy
# SOLs.csv
# U.csv
# SOLw.csv
# K.csv
# validatiaon
# .ipynb_checkpoints
# Untitled.ipynb
# Added data constraint of shape (9000000, 1)
# Contents of folder '../.././treino2/':
# V.csv
# T.csv
# U.npy
# V.npy
# K.npy
# SOLs.npy
# T.npy
# SOLw.npy
# SOLs.csv
# U.csv
# SOLw.csv
# .ipynb_checkpoints
# K.csv
# Added data constraint of shape (20000000, 1)
# Contents of folder '../.././treino3/':
# U.npy
# V.npy
# K.npy
# SOLs.npy
# T.npy
# SOLw.npy
# Added data constraint of shape (10000000, 1)
# [01:30:48] - Solving for Domain initial_conditions, iteration 0
# [01:30:48] - attempting to restore from: outputs/fhn3Ppred/initial_conditions
# [01:30:48] - optimizer checkpoint not found
# [01:30:48] - model network.0.pth not found
# [01:30:56] - [step:          0] record constraint batch time:  5.226e-02s
# [01:30:58] - [step:          0] record validators time:  2.110e+00s
# [01:30:58] - [step:          0] record monitor time:  2.352e-02s
# [01:30:58] - [step:          0] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:30:58] - [step:          0] loss:  1.719e+04
# [01:30:58] - Attempting cuda graph building, this may take a bit...
# [01:31:00] - [step:        100] loss:  2.390e+03, time/iteration:  1.785e+01 ms
# [01:31:01] - [step:        200] loss:  2.369e+03, time/iteration:  1.279e+01 ms
# [01:31:02] - [step:        300] loss:  2.314e+03, time/iteration:  1.265e+01 ms
# [01:31:03] - [step:        400] loss:  2.241e+03, time/iteration:  1.270e+01 ms
# [01:31:05] - [step:        500] loss:  2.225e+03, time/iteration:  1.275e+01 ms
# [01:31:06] - [step:        600] loss:  2.212e+03, time/iteration:  1.284e+01 ms
# [01:31:07] - [step:        700] loss:  2.205e+03, time/iteration:  1.277e+01 ms
# [01:31:08] - [step:        800] loss:  2.167e+03, time/iteration:  1.272e+01 ms
# [01:31:10] - [step:        900] loss:  2.213e+03, time/iteration:  1.282e+01 ms
# [01:31:14] - [step:       1000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:31:14] - [step:       1000] loss:  2.127e+03, time/iteration:  4.593e+01 ms
# [01:31:17] - [step:       1100] loss:  2.144e+03, time/iteration:  2.230e+01 ms
# [01:31:19] - [step:       1200] loss:  2.125e+03, time/iteration:  2.194e+01 ms
# [01:31:21] - [step:       1300] loss:  2.136e+03, time/iteration:  2.228e+01 ms
# [01:31:23] - [step:       1400] loss:  2.139e+03, time/iteration:  2.220e+01 ms
# [01:31:26] - [step:       1500] loss:  2.098e+03, time/iteration:  2.463e+01 ms
# [01:31:28] - [step:       1600] loss:  2.095e+03, time/iteration:  2.240e+01 ms
# [01:31:30] - [step:       1700] loss:  2.063e+03, time/iteration:  2.220e+01 ms
# [01:31:33] - [step:       1800] loss:  2.003e+03, time/iteration:  3.072e+01 ms
# [01:31:35] - [step:       1900] loss:  2.006e+03, time/iteration:  2.261e+01 ms
# [01:31:42] - [step:       2000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:31:42] - [step:       2000] loss:  1.941e+03, time/iteration:  6.829e+01 ms
# [01:31:44] - [step:       2100] loss:  1.955e+03, time/iteration:  2.134e+01 ms
# [01:31:47] - [step:       2200] loss:  1.933e+03, time/iteration:  2.254e+01 ms
# [01:31:49] - [step:       2300] loss:  1.927e+03, time/iteration:  2.111e+01 ms
# [01:31:51] - [step:       2400] loss:  1.886e+03, time/iteration:  2.107e+01 ms
# [01:31:53] - [step:       2500] loss:  1.863e+03, time/iteration:  2.126e+01 ms
# [01:31:55] - [step:       2600] loss:  1.816e+03, time/iteration:  2.112e+01 ms
# [01:31:57] - [step:       2700] loss:  1.799e+03, time/iteration:  2.125e+01 ms
# [01:31:59] - [step:       2800] loss:  1.800e+03, time/iteration:  2.143e+01 ms
# [01:32:02] - [step:       2900] loss:  1.780e+03, time/iteration:  2.126e+01 ms
# [01:32:07] - [step:       3000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:32:07] - [step:       3000] loss:  1.768e+03, time/iteration:  5.425e+01 ms
# [01:32:09] - [step:       3100] loss:  1.716e+03, time/iteration:  1.994e+01 ms
# [01:32:11] - [step:       3200] loss:  1.706e+03, time/iteration:  1.998e+01 ms
# [01:32:13] - [step:       3300] loss:  1.685e+03, time/iteration:  2.011e+01 ms
# [01:32:15] - [step:       3400] loss:  1.698e+03, time/iteration:  2.006e+01 ms
# [01:32:17] - [step:       3500] loss:  1.675e+03, time/iteration:  2.466e+01 ms
# [01:32:20] - [step:       3600] loss:  1.656e+03, time/iteration:  2.445e+01 ms
# [01:32:22] - [step:       3700] loss:  1.639e+03, time/iteration:  2.014e+01 ms
# [01:32:24] - [step:       3800] loss:  1.619e+03, time/iteration:  2.005e+01 ms
# [01:32:28] - [step:       3900] loss:  1.581e+03, time/iteration:  3.802e+01 ms
# [01:32:35] - [step:       4000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:32:35] - [step:       4000] loss:  1.499e+03, time/iteration:  7.020e+01 ms
# [01:32:36] - [step:       4100] loss:  1.430e+03, time/iteration:  1.745e+01 ms
# [01:32:38] - [step:       4200] loss:  1.430e+03, time/iteration:  1.736e+01 ms
# [01:32:40] - [step:       4300] loss:  1.370e+03, time/iteration:  1.743e+01 ms
# [01:32:42] - [step:       4400] loss:  1.376e+03, time/iteration:  1.726e+01 ms
# [01:32:43] - [step:       4500] loss:  1.345e+03, time/iteration:  1.749e+01 ms
# [01:32:45] - [step:       4600] loss:  1.368e+03, time/iteration:  1.736e+01 ms
# [01:32:47] - [step:       4700] loss:  1.243e+03, time/iteration:  1.741e+01 ms
# [01:32:49] - [step:       4800] loss:  1.239e+03, time/iteration:  1.744e+01 ms
# [01:32:50] - [step:       4900] loss:  1.194e+03, time/iteration:  1.745e+01 ms
# [01:32:57] - [step:       5000] record validators time:  1.605e+00s
# [01:32:57] - [step:       5000] record monitor time:  2.223e-02s
# [01:32:57] - [step:       5000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:32:57] - [step:       5000] loss:  1.159e+03, time/iteration:  6.670e+01 ms
# [01:32:59] - [step:       5100] loss:  1.089e+03, time/iteration:  1.813e+01 ms
# [01:33:01] - [step:       5200] loss:  1.106e+03, time/iteration:  1.797e+01 ms
# [01:33:03] - [step:       5300] loss:  9.537e+02, time/iteration:  2.631e+01 ms
# [01:33:05] - [step:       5400] loss:  8.678e+02, time/iteration:  1.863e+01 ms
# [01:33:07] - [step:       5500] loss:  8.719e+02, time/iteration:  1.811e+01 ms
# [01:33:09] - [step:       5600] loss:  8.024e+02, time/iteration:  1.818e+01 ms
# [01:33:11] - [step:       5700] loss:  7.844e+02, time/iteration:  1.805e+01 ms
# [01:33:12] - [step:       5800] loss:  7.522e+02, time/iteration:  1.815e+01 ms
# [01:33:15] - [step:       5900] loss:  7.375e+02, time/iteration:  2.683e+01 ms
# [01:33:20] - [step:       6000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:33:20] - [step:       6000] loss:  7.474e+02, time/iteration:  5.121e+01 ms
# [01:33:22] - [step:       6100] loss:  7.272e+02, time/iteration:  1.922e+01 ms
# [01:33:24] - [step:       6200] loss:  7.135e+02, time/iteration:  1.670e+01 ms
# [01:33:25] - [step:       6300] loss:  7.306e+02, time/iteration:  1.655e+01 ms
# [01:33:27] - [step:       6400] loss:  6.884e+02, time/iteration:  1.642e+01 ms
# [01:33:29] - [step:       6500] loss:  6.868e+02, time/iteration:  1.675e+01 ms
# [01:33:30] - [step:       6600] loss:  6.812e+02, time/iteration:  1.678e+01 ms
# [01:33:32] - [step:       6700] loss:  6.609e+02, time/iteration:  1.676e+01 ms
# [01:33:34] - [step:       6800] loss:  6.993e+02, time/iteration:  1.676e+01 ms
# [01:33:35] - [step:       6900] loss:  6.457e+02, time/iteration:  1.657e+01 ms
# [01:33:40] - [step:       7000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:33:40] - [step:       7000] loss:  6.326e+02, time/iteration:  4.955e+01 ms
# [01:33:43] - [step:       7100] loss:  6.129e+02, time/iteration:  2.606e+01 ms
# [01:33:45] - [step:       7200] loss:  6.070e+02, time/iteration:  1.760e+01 ms
# [01:33:47] - [step:       7300] loss:  6.340e+02, time/iteration:  1.771e+01 ms
# [01:33:48] - [step:       7400] loss:  6.670e+02, time/iteration:  1.770e+01 ms
# [01:33:50] - [step:       7500] loss:  6.462e+02, time/iteration:  1.742e+01 ms
# [01:33:52] - [step:       7600] loss:  5.750e+02, time/iteration:  1.744e+01 ms
# [01:33:54] - [step:       7700] loss:  5.616e+02, time/iteration:  1.745e+01 ms
# [01:33:57] - [step:       7800] loss:  5.743e+02, time/iteration:  3.296e+01 ms
# [01:34:00] - [step:       7900] loss:  5.490e+02, time/iteration:  3.198e+01 ms
# [01:34:05] - [step:       8000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:34:05] - [step:       8000] loss:  5.647e+02, time/iteration:  5.334e+01 ms
# [01:34:07] - [step:       8100] loss:  5.633e+02, time/iteration:  1.790e+01 ms
# [01:34:09] - [step:       8200] loss:  5.768e+02, time/iteration:  1.780e+01 ms
# [01:34:11] - [step:       8300] loss:  6.368e+02, time/iteration:  1.794e+01 ms
# [01:34:13] - [step:       8400] loss:  5.975e+02, time/iteration:  1.789e+01 ms
# [01:34:14] - [step:       8500] loss:  5.227e+02, time/iteration:  1.795e+01 ms
# [01:34:16] - [step:       8600] loss:  5.524e+02, time/iteration:  1.773e+01 ms
# [01:34:18] - [step:       8700] loss:  5.397e+02, time/iteration:  1.787e+01 ms
# [01:34:21] - [step:       8800] loss:  5.491e+02, time/iteration:  2.618e+01 ms
# [01:34:22] - [step:       8900] loss:  5.187e+02, time/iteration:  1.841e+01 ms
# [01:34:28] - [step:       9000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:34:28] - [step:       9000] loss:  5.242e+02, time/iteration:  5.340e+01 ms
# [01:34:30] - [step:       9100] loss:  5.160e+02, time/iteration:  1.816e+01 ms
# [01:34:31] - [step:       9200] loss:  5.280e+02, time/iteration:  1.805e+01 ms
# [01:34:33] - [step:       9300] loss:  5.181e+02, time/iteration:  1.795e+01 ms
# [01:34:35] - [step:       9400] loss:  5.176e+02, time/iteration:  1.785e+01 ms
# [01:34:37] - [step:       9500] loss:  5.181e+02, time/iteration:  1.798e+01 ms
# [01:34:39] - [step:       9600] loss:  6.090e+02, time/iteration:  1.823e+01 ms
# [01:34:40] - [step:       9700] loss:  5.164e+02, time/iteration:  1.799e+01 ms
# [01:34:43] - [step:       9800] loss:  4.825e+02, time/iteration:  2.666e+01 ms
# [01:34:45] - [step:       9900] loss:  5.089e+02, time/iteration:  1.835e+01 ms
# [01:34:52] - [step:      10000] record validators time:  1.842e+00s
# [01:34:52] - [step:      10000] record monitor time:  2.186e-02s
# [01:34:52] - [step:      10000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:34:52] - [step:      10000] loss:  6.579e+02, time/iteration:  7.118e+01 ms
# [01:34:54] - [step:      10100] loss:  4.919e+02, time/iteration:  1.774e+01 ms
# [01:34:55] - [step:      10200] loss:  5.749e+02, time/iteration:  1.770e+01 ms
# [01:34:57] - [step:      10300] loss:  4.825e+02, time/iteration:  1.756e+01 ms
# [01:34:59] - [step:      10400] loss:  5.385e+02, time/iteration:  1.787e+01 ms
# [01:35:01] - [step:      10500] loss:  5.090e+02, time/iteration:  1.755e+01 ms
# [01:35:03] - [step:      10600] loss:  5.160e+02, time/iteration:  2.657e+01 ms
# [01:35:05] - [step:      10700] loss:  4.687e+02, time/iteration:  1.795e+01 ms
# [01:35:07] - [step:      10800] loss:  5.323e+02, time/iteration:  1.780e+01 ms
# [01:35:09] - [step:      10900] loss:  4.759e+02, time/iteration:  1.793e+01 ms
# [01:35:14] - [step:      11000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:35:14] - [step:      11000] loss:  4.876e+02, time/iteration:  5.078e+01 ms
# [01:35:16] - [step:      11100] loss:  4.608e+02, time/iteration:  1.759e+01 ms
# [01:35:17] - [step:      11200] loss:  4.668e+02, time/iteration:  1.734e+01 ms
# [01:35:19] - [step:      11300] loss:  4.908e+02, time/iteration:  1.753e+01 ms
# [01:35:21] - [step:      11400] loss:  4.727e+02, time/iteration:  1.762e+01 ms
# [01:35:23] - [step:      11500] loss:  4.758e+02, time/iteration:  1.743e+01 ms
# [01:35:24] - [step:      11600] loss:  4.848e+02, time/iteration:  1.763e+01 ms
# [01:35:28] - [step:      11700] loss:  4.973e+02, time/iteration:  3.313e+01 ms
# [01:35:31] - [step:      11800] loss:  4.351e+02, time/iteration:  3.331e+01 ms
# [01:35:33] - [step:      11900] loss:  4.654e+02, time/iteration:  1.761e+01 ms
# [01:35:38] - [step:      12000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:35:38] - [step:      12000] loss:  4.582e+02, time/iteration:  5.417e+01 ms
# [01:35:40] - [step:      12100] loss:  4.407e+02, time/iteration:  1.808e+01 ms
# [01:35:42] - [step:      12200] loss:  5.128e+02, time/iteration:  1.825e+01 ms
# [01:35:45] - [step:      12300] loss:  4.692e+02, time/iteration:  2.657e+01 ms
# [01:35:46] - [step:      12400] loss:  4.765e+02, time/iteration:  1.862e+01 ms
# [01:35:48] - [step:      12500] loss:  4.296e+02, time/iteration:  1.812e+01 ms
# [01:35:50] - [step:      12600] loss:  5.254e+02, time/iteration:  1.819e+01 ms
# [01:35:52] - [step:      12700] loss:  4.931e+02, time/iteration:  1.797e+01 ms
# [01:35:54] - [step:      12800] loss:  4.314e+02, time/iteration:  1.814e+01 ms
# [01:35:55] - [step:      12900] loss:  4.241e+02, time/iteration:  1.802e+01 ms
# [01:36:01] - [step:      13000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:36:01] - [step:      13000] loss:  4.112e+02, time/iteration:  5.279e+01 ms
# [01:36:03] - [step:      13100] loss:  4.547e+02, time/iteration:  1.936e+01 ms
# [01:36:05] - [step:      13200] loss:  4.466e+02, time/iteration:  1.937e+01 ms
# [01:36:06] - [step:      13300] loss:  4.593e+02, time/iteration:  1.924e+01 ms
# [01:36:08] - [step:      13400] loss:  4.450e+02, time/iteration:  1.921e+01 ms
# [01:36:10] - [step:      13500] loss:  4.682e+02, time/iteration:  1.916e+01 ms
# [01:36:12] - [step:      13600] loss:  4.142e+02, time/iteration:  1.924e+01 ms
# [01:36:15] - [step:      13700] loss:  4.416e+02, time/iteration:  2.838e+01 ms
# [01:36:17] - [step:      13800] loss:  4.874e+02, time/iteration:  1.923e+01 ms
# [01:36:19] - [step:      13900] loss:  4.152e+02, time/iteration:  1.946e+01 ms
# [01:36:24] - [step:      14000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:36:24] - [step:      14000] loss:  4.259e+02, time/iteration:  5.218e+01 ms
# [01:36:27] - [step:      14100] loss:  3.879e+02, time/iteration:  3.243e+01 ms
# [01:36:30] - [step:      14200] loss:  4.027e+02, time/iteration:  2.097e+01 ms
# [01:36:32] - [step:      14300] loss:  4.049e+02, time/iteration:  2.105e+01 ms
# [01:36:34] - [step:      14400] loss:  3.864e+02, time/iteration:  2.133e+01 ms
# [01:36:36] - [step:      14500] loss:  4.729e+02, time/iteration:  2.131e+01 ms
# [01:36:38] - [step:      14600] loss:  3.682e+02, time/iteration:  2.126e+01 ms
# [01:36:40] - [step:      14700] loss:  3.902e+02, time/iteration:  2.098e+01 ms
# [01:36:42] - [step:      14800] loss:  3.736e+02, time/iteration:  2.126e+01 ms
# [01:36:44] - [step:      14900] loss:  3.670e+02, time/iteration:  2.127e+01 ms
# [01:36:51] - [step:      15000] record validators time:  1.574e+00s
# [01:36:51] - [step:      15000] record monitor time:  2.370e-02s
# [01:36:51] - [step:      15000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:36:51] - [step:      15000] loss:  3.545e+02, time/iteration:  6.999e+01 ms
# [01:36:54] - [step:      15100] loss:  3.867e+02, time/iteration:  2.187e+01 ms
# [01:36:56] - [step:      15200] loss:  3.693e+02, time/iteration:  2.184e+01 ms
# [01:36:58] - [step:      15300] loss:  4.075e+02, time/iteration:  2.170e+01 ms
# [01:37:00] - [step:      15400] loss:  4.851e+02, time/iteration:  2.195e+01 ms
# [01:37:02] - [step:      15500] loss:  4.035e+02, time/iteration:  2.179e+01 ms
# [01:37:04] - [step:      15600] loss:  3.606e+02, time/iteration:  2.177e+01 ms
# [01:37:10] - [step:      15700] loss:  3.487e+02, time/iteration:  5.044e+01 ms
# [01:37:12] - [step:      15800] loss:  4.127e+02, time/iteration:  2.617e+01 ms
# [01:37:15] - [step:      15900] loss:  2.988e+02, time/iteration:  2.608e+01 ms
# [01:37:21] - [step:      16000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:37:21] - [step:      16000] loss:  3.180e+02, time/iteration:  5.767e+01 ms
# [01:37:23] - [step:      16100] loss:  3.727e+02, time/iteration:  2.048e+01 ms
# [01:37:25] - [step:      16200] loss:  3.935e+02, time/iteration:  2.027e+01 ms
# [01:37:27] - [step:      16300] loss:  3.091e+02, time/iteration:  2.054e+01 ms
# [01:37:29] - [step:      16400] loss:  3.150e+02, time/iteration:  2.037e+01 ms
# [01:37:31] - [step:      16500] loss:  3.021e+02, time/iteration:  2.035e+01 ms
# [01:37:33] - [step:      16600] loss:  3.210e+02, time/iteration:  2.042e+01 ms
# [01:37:35] - [step:      16700] loss:  2.976e+02, time/iteration:  2.046e+01 ms
# [01:37:37] - [step:      16800] loss:  3.187e+02, time/iteration:  2.038e+01 ms
# [01:37:39] - [step:      16900] loss:  2.700e+02, time/iteration:  2.042e+01 ms
# [01:37:44] - [step:      17000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:37:44] - [step:      17000] loss:  2.836e+02, time/iteration:  5.348e+01 ms
# [01:37:46] - [step:      17100] loss:  3.088e+02, time/iteration:  2.183e+01 ms
# [01:37:49] - [step:      17200] loss:  2.759e+02, time/iteration:  2.185e+01 ms
# [01:37:51] - [step:      17300] loss:  3.348e+02, time/iteration:  2.169e+01 ms
# [01:37:53] - [step:      17400] loss:  3.240e+02, time/iteration:  2.166e+01 ms
# [01:37:55] - [step:      17500] loss:  2.685e+02, time/iteration:  2.165e+01 ms
# [01:37:59] - [step:      17600] loss:  2.475e+02, time/iteration:  3.922e+01 ms
# [01:38:01] - [step:      17700] loss:  2.516e+02, time/iteration:  2.231e+01 ms
# [01:38:03] - [step:      17800] loss:  2.610e+02, time/iteration:  2.205e+01 ms
# [01:38:06] - [step:      17900] loss:  2.341e+02, time/iteration:  2.182e+01 ms
# [01:38:11] - [step:      18000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:38:11] - [step:      18000] loss:  2.367e+02, time/iteration:  5.759e+01 ms
# [01:38:14] - [step:      18100] loss:  2.718e+02, time/iteration:  2.225e+01 ms
# [01:38:16] - [step:      18200] loss:  2.576e+02, time/iteration:  2.233e+01 ms
# [01:38:18] - [step:      18300] loss:  3.497e+02, time/iteration:  2.238e+01 ms
# [01:38:20] - [step:      18400] loss:  2.441e+02, time/iteration:  2.223e+01 ms
# [01:38:23] - [step:      18500] loss:  2.609e+02, time/iteration:  2.241e+01 ms
# [01:38:25] - [step:      18600] loss:  2.358e+02, time/iteration:  2.223e+01 ms
# [01:38:27] - [step:      18700] loss:  2.185e+02, time/iteration:  2.238e+01 ms
# [01:38:29] - [step:      18800] loss:  2.652e+02, time/iteration:  2.218e+01 ms
# [01:38:31] - [step:      18900] loss:  2.407e+02, time/iteration:  2.249e+01 ms
# [01:38:37] - [step:      19000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:38:37] - [step:      19000] loss:  2.241e+02, time/iteration:  5.542e+01 ms
# [01:38:39] - [step:      19100] loss:  1.989e+02, time/iteration:  2.371e+01 ms
# [01:38:42] - [step:      19200] loss:  2.323e+02, time/iteration:  2.387e+01 ms
# [01:38:44] - [step:      19300] loss:  2.753e+02, time/iteration:  2.385e+01 ms
# [01:38:47] - [step:      19400] loss:  2.289e+02, time/iteration:  3.258e+01 ms
# [01:38:50] - [step:      19500] loss:  2.190e+02, time/iteration:  2.376e+01 ms
# [01:38:55] - [step:      19600] loss:  2.596e+02, time/iteration:  5.345e+01 ms
# [01:38:58] - [step:      19700] loss:  2.442e+02, time/iteration:  2.392e+01 ms
# [01:39:00] - [step:      19800] loss:  2.678e+02, time/iteration:  2.375e+01 ms
# [01:39:02] - [step:      19900] loss:  2.207e+02, time/iteration:  2.366e+01 ms
# [01:39:10] - [step:      20000] record validators time:  1.501e+00s
# [01:39:10] - [step:      20000] record monitor time:  2.218e-02s
# [01:39:10] - [step:      20000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:39:10] - [step:      20000] loss:  2.201e+02, time/iteration:  7.472e+01 ms
# [01:39:12] - [step:      20100] loss:  2.550e+02, time/iteration:  2.400e+01 ms
# [01:39:15] - [step:      20200] loss:  2.310e+02, time/iteration:  2.414e+01 ms
# [01:39:17] - [step:      20300] loss:  3.283e+02, time/iteration:  2.403e+01 ms
# [01:39:19] - [step:      20400] loss:  2.177e+02, time/iteration:  2.387e+01 ms
# [01:39:22] - [step:      20500] loss:  1.867e+02, time/iteration:  2.407e+01 ms
# [01:39:24] - [step:      20600] loss:  1.914e+02, time/iteration:  2.396e+01 ms
# [01:39:27] - [step:      20700] loss:  2.355e+02, time/iteration:  2.393e+01 ms
# [01:39:29] - [step:      20800] loss:  1.916e+02, time/iteration:  2.401e+01 ms
# [01:39:31] - [step:      20900] loss:  2.287e+02, time/iteration:  2.409e+01 ms
# [01:39:37] - [step:      21000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:39:37] - [step:      21000] loss:  1.971e+02, time/iteration:  5.708e+01 ms
# [01:39:40] - [step:      21100] loss:  1.995e+02, time/iteration:  3.374e+01 ms
# [01:39:43] - [step:      21200] loss:  1.810e+02, time/iteration:  2.519e+01 ms
# [01:39:45] - [step:      21300] loss:  1.768e+02, time/iteration:  2.510e+01 ms
# [01:39:48] - [step:      21400] loss:  6.021e+02, time/iteration:  2.538e+01 ms
# [01:39:51] - [step:      21500] loss:  1.729e+02, time/iteration:  3.453e+01 ms
# [01:39:54] - [step:      21600] loss:  1.706e+02, time/iteration:  2.532e+01 ms
# [01:39:57] - [step:      21700] loss:  1.933e+02, time/iteration:  2.523e+01 ms
# [01:39:59] - [step:      21800] loss:  1.745e+02, time/iteration:  2.521e+01 ms
# [01:40:02] - [step:      21900] loss:  2.375e+02, time/iteration:  2.525e+01 ms
# [01:40:08] - [step:      22000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:40:08] - [step:      22000] loss:  1.744e+02, time/iteration:  6.193e+01 ms
# [01:40:10] - [step:      22100] loss:  1.749e+02, time/iteration:  2.493e+01 ms
# [01:40:13] - [step:      22200] loss:  1.744e+02, time/iteration:  2.494e+01 ms
# [01:40:15] - [step:      22300] loss:  2.563e+02, time/iteration:  2.491e+01 ms
# [01:40:18] - [step:      22400] loss:  2.872e+02, time/iteration:  2.485e+01 ms
# [01:40:20] - [step:      22500] loss:  1.725e+02, time/iteration:  2.498e+01 ms
# [01:40:23] - [step:      22600] loss:  1.814e+02, time/iteration:  2.469e+01 ms
# [01:40:25] - [step:      22700] loss:  2.699e+02, time/iteration:  2.477e+01 ms
# [01:40:28] - [step:      22800] loss:  2.091e+02, time/iteration:  2.499e+01 ms
# [01:40:31] - [step:      22900] loss:  1.879e+02, time/iteration:  3.413e+01 ms
# [01:40:37] - [step:      23000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:40:37] - [step:      23000] loss:  1.889e+02, time/iteration:  5.782e+01 ms
# [01:40:39] - [step:      23100] loss:  1.834e+02, time/iteration:  2.521e+01 ms
# [01:40:42] - [step:      23200] loss:  1.918e+02, time/iteration:  2.507e+01 ms
# [01:40:44] - [step:      23300] loss:  1.601e+02, time/iteration:  2.526e+01 ms
# [01:40:47] - [step:      23400] loss:  2.887e+02, time/iteration:  2.532e+01 ms
# [01:40:53] - [step:      23500] loss:  2.144e+02, time/iteration:  5.555e+01 ms
# [01:40:55] - [step:      23600] loss:  1.591e+02, time/iteration:  2.524e+01 ms
# [01:40:58] - [step:      23700] loss:  1.816e+02, time/iteration:  2.527e+01 ms
# [01:41:00] - [step:      23800] loss:  1.633e+02, time/iteration:  2.545e+01 ms
# [01:41:03] - [step:      23900] loss:  2.035e+02, time/iteration:  2.520e+01 ms
# [01:41:09] - [step:      24000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:41:09] - [step:      24000] loss:  2.388e+02, time/iteration:  6.110e+01 ms
# [01:41:11] - [step:      24100] loss:  1.859e+02, time/iteration:  2.699e+01 ms
# [01:41:14] - [step:      24200] loss:  1.572e+02, time/iteration:  2.703e+01 ms
# [01:41:17] - [step:      24300] loss:  1.744e+02, time/iteration:  2.682e+01 ms
# [01:41:20] - [step:      24400] loss:  1.451e+02, time/iteration:  2.692e+01 ms
# [01:41:22] - [step:      24500] loss:  2.000e+02, time/iteration:  2.694e+01 ms
# [01:41:26] - [step:      24600] loss:  1.548e+02, time/iteration:  3.519e+01 ms
# [01:41:28] - [step:      24700] loss:  2.922e+02, time/iteration:  2.738e+01 ms
# [01:41:31] - [step:      24800] loss:  1.320e+02, time/iteration:  2.706e+01 ms
# [01:41:34] - [step:      24900] loss:  1.605e+02, time/iteration:  2.706e+01 ms
# [01:41:41] - [step:      25000] record validators time:  1.608e+00s
# [01:41:42] - [step:      25000] record monitor time:  2.275e-02s
# [01:41:42] - [step:      25000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:41:42] - [step:      25000] loss:  1.982e+02, time/iteration:  7.632e+01 ms
# [01:41:44] - [step:      25100] loss:  2.719e+02, time/iteration:  2.620e+01 ms
# [01:41:47] - [step:      25200] loss:  1.795e+02, time/iteration:  2.631e+01 ms
# [01:41:49] - [step:      25300] loss:  1.348e+02, time/iteration:  2.634e+01 ms
# [01:41:53] - [step:      25400] loss:  2.133e+02, time/iteration:  3.518e+01 ms
# [01:41:56] - [step:      25500] loss:  2.143e+02, time/iteration:  2.659e+01 ms
# [01:41:58] - [step:      25600] loss:  1.863e+02, time/iteration:  2.632e+01 ms
# [01:42:01] - [step:      25700] loss:  1.726e+02, time/iteration:  2.631e+01 ms
# [01:42:03] - [step:      25800] loss:  2.530e+02, time/iteration:  2.637e+01 ms
# [01:42:06] - [step:      25900] loss:  2.177e+02, time/iteration:  2.661e+01 ms
# [01:42:12] - [step:      26000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:42:12] - [step:      26000] loss:  2.266e+02, time/iteration:  6.215e+01 ms
# [01:42:15] - [step:      26100] loss:  1.702e+02, time/iteration:  2.608e+01 ms
# [01:42:18] - [step:      26200] loss:  1.518e+02, time/iteration:  2.603e+01 ms
# [01:42:20] - [step:      26300] loss:  1.511e+02, time/iteration:  2.577e+01 ms
# [01:42:24] - [step:      26400] loss:  1.671e+02, time/iteration:  3.435e+01 ms
# [01:42:26] - [step:      26500] loss:  1.483e+02, time/iteration:  2.588e+01 ms
# [01:42:29] - [step:      26600] loss:  2.061e+02, time/iteration:  2.586e+01 ms
# [01:42:31] - [step:      26700] loss:  1.173e+02, time/iteration:  2.592e+01 ms
# [01:42:34] - [step:      26800] loss:  1.503e+02, time/iteration:  2.587e+01 ms
# [01:42:37] - [step:      26900] loss:  1.387e+02, time/iteration:  2.578e+01 ms
# [01:42:42] - [step:      27000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:42:42] - [step:      27000] loss:  1.915e+02, time/iteration:  5.884e+01 ms
# [01:42:45] - [step:      27100] loss:  1.313e+02, time/iteration:  2.820e+01 ms
# [01:42:48] - [step:      27200] loss:  1.718e+02, time/iteration:  2.805e+01 ms
# [01:42:51] - [step:      27300] loss:  1.230e+02, time/iteration:  2.823e+01 ms
# [01:42:57] - [step:      27400] loss:  1.772e+02, time/iteration:  5.777e+01 ms
# [01:42:59] - [step:      27500] loss:  1.191e+02, time/iteration:  2.857e+01 ms
# [01:43:02] - [step:      27600] loss:  2.294e+02, time/iteration:  2.831e+01 ms
# [01:43:05] - [step:      27700] loss:  1.428e+02, time/iteration:  2.830e+01 ms
# [01:43:08] - [step:      27800] loss:  1.642e+02, time/iteration:  2.844e+01 ms
# [01:43:11] - [step:      27900] loss:  1.788e+02, time/iteration:  2.837e+01 ms
# [01:43:17] - [step:      28000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:43:17] - [step:      28000] loss:  2.192e+02, time/iteration:  6.388e+01 ms
# [01:43:20] - [step:      28100] loss:  1.555e+02, time/iteration:  3.268e+01 ms
# [01:43:24] - [step:      28200] loss:  1.085e+02, time/iteration:  3.248e+01 ms
# [01:43:27] - [step:      28300] loss:  1.127e+02, time/iteration:  2.807e+01 ms
# [01:43:29] - [step:      28400] loss:  1.389e+02, time/iteration:  2.844e+01 ms
# [01:43:32] - [step:      28500] loss:  2.409e+02, time/iteration:  2.811e+01 ms
# [01:43:35] - [step:      28600] loss:  3.049e+02, time/iteration:  2.833e+01 ms
# [01:43:38] - [step:      28700] loss:  1.211e+02, time/iteration:  2.831e+01 ms
# [01:43:41] - [step:      28800] loss:  1.366e+02, time/iteration:  2.832e+01 ms
# [01:43:44] - [step:      28900] loss:  1.763e+02, time/iteration:  2.813e+01 ms
# [01:43:50] - [step:      29000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:43:50] - [step:      29000] loss:  1.116e+02, time/iteration:  6.157e+01 ms
# [01:43:52] - [step:      29100] loss:  1.120e+02, time/iteration:  2.812e+01 ms
# [01:43:55] - [step:      29200] loss:  1.200e+02, time/iteration:  2.784e+01 ms
# [01:43:59] - [step:      29300] loss:  1.135e+02, time/iteration:  3.762e+01 ms
# [01:44:02] - [step:      29400] loss:  1.827e+02, time/iteration:  2.815e+01 ms
# [01:44:05] - [step:      29500] loss:  1.981e+02, time/iteration:  2.795e+01 ms
# [01:44:07] - [step:      29600] loss:  1.122e+02, time/iteration:  2.809e+01 ms
# [01:44:10] - [step:      29700] loss:  1.572e+02, time/iteration:  2.798e+01 ms
# [01:44:13] - [step:      29800] loss:  3.146e+02, time/iteration:  2.812e+01 ms
# [01:44:17] - [step:      29900] loss:  2.061e+02, time/iteration:  3.695e+01 ms
# [01:44:25] - [step:      30000] record validators time:  1.566e+00s
# [01:44:25] - [step:      30000] record monitor time:  2.200e-02s
# [01:44:25] - [step:      30000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:44:25] - [step:      30000] loss:  1.979e+02, time/iteration:  7.972e+01 ms
# [01:44:27] - [step:      30100] loss:  1.144e+02, time/iteration:  2.750e+01 ms
# [01:44:30] - [step:      30200] loss:  3.749e+02, time/iteration:  2.740e+01 ms
# [01:44:33] - [step:      30300] loss:  1.047e+02, time/iteration:  2.731e+01 ms
# [01:44:36] - [step:      30400] loss:  1.877e+02, time/iteration:  2.758e+01 ms
# [01:44:38] - [step:      30500] loss:  1.032e+02, time/iteration:  2.734e+01 ms
# [01:44:41] - [step:      30600] loss:  1.750e+02, time/iteration:  2.726e+01 ms
# [01:44:44] - [step:      30700] loss:  1.148e+02, time/iteration:  2.744e+01 ms
# [01:44:47] - [step:      30800] loss:  2.064e+02, time/iteration:  2.749e+01 ms
# [01:44:49] - [step:      30900] loss:  1.070e+02, time/iteration:  2.752e+01 ms
# [01:44:55] - [step:      31000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:44:55] - [step:      31000] loss:  1.155e+02, time/iteration:  6.068e+01 ms
# [01:44:58] - [step:      31100] loss:  1.274e+02, time/iteration:  2.815e+01 ms
# [01:45:01] - [step:      31200] loss:  1.547e+02, time/iteration:  2.819e+01 ms
# [01:45:07] - [step:      31300] loss:  1.185e+02, time/iteration:  5.816e+01 ms
# [01:45:10] - [step:      31400] loss:  2.448e+02, time/iteration:  2.827e+01 ms
# [01:45:13] - [step:      31500] loss:  1.118e+02, time/iteration:  2.808e+01 ms
# [01:45:15] - [step:      31600] loss:  1.280e+02, time/iteration:  2.814e+01 ms
# [01:45:19] - [step:      31700] loss:  9.772e+01, time/iteration:  3.731e+01 ms
# [01:45:22] - [step:      31800] loss:  1.458e+02, time/iteration:  2.843e+01 ms
# [01:45:25] - [step:      31900] loss:  1.005e+02, time/iteration:  2.808e+01 ms
# [01:45:31] - [step:      32000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:45:31] - [step:      32000] loss:  1.077e+02, time/iteration:  6.420e+01 ms
# [01:45:34] - [step:      32100] loss:  1.049e+02, time/iteration:  2.785e+01 ms
# [01:45:37] - [step:      32200] loss:  1.071e+02, time/iteration:  2.792e+01 ms
# [01:45:40] - [step:      32300] loss:  1.639e+02, time/iteration:  2.770e+01 ms
# [01:45:42] - [step:      32400] loss:  3.760e+02, time/iteration:  2.777e+01 ms
# [01:45:45] - [step:      32500] loss:  9.471e+01, time/iteration:  2.770e+01 ms
# [01:45:48] - [step:      32600] loss:  1.211e+02, time/iteration:  2.784e+01 ms
# [01:45:51] - [step:      32700] loss:  1.775e+02, time/iteration:  2.776e+01 ms
# [01:45:53] - [step:      32800] loss:  2.919e+02, time/iteration:  2.804e+01 ms
# [01:45:56] - [step:      32900] loss:  1.017e+02, time/iteration:  2.783e+01 ms
# [01:46:02] - [step:      33000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:46:02] - [step:      33000] loss:  1.093e+02, time/iteration:  6.111e+01 ms
# [01:46:05] - [step:      33100] loss:  1.675e+02, time/iteration:  2.892e+01 ms
# [01:46:09] - [step:      33200] loss:  1.099e+02, time/iteration:  3.804e+01 ms
# [01:46:12] - [step:      33300] loss:  8.983e+01, time/iteration:  2.956e+01 ms
# [01:46:16] - [step:      33400] loss:  9.139e+01, time/iteration:  3.723e+01 ms
# [01:46:19] - [step:      33500] loss:  1.274e+02, time/iteration:  2.955e+01 ms
# [01:46:22] - [step:      33600] loss:  1.521e+02, time/iteration:  2.900e+01 ms
# [01:46:24] - [step:      33700] loss:  1.043e+02, time/iteration:  2.897e+01 ms
# [01:46:27] - [step:      33800] loss:  1.087e+02, time/iteration:  2.889e+01 ms
# [01:46:30] - [step:      33900] loss:  1.315e+02, time/iteration:  2.895e+01 ms
# [01:46:37] - [step:      34000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:46:37] - [step:      34000] loss:  8.948e+01, time/iteration:  6.453e+01 ms
# [01:46:40] - [step:      34100] loss:  9.411e+01, time/iteration:  2.795e+01 ms
# [01:46:42] - [step:      34200] loss:  1.487e+02, time/iteration:  2.793e+01 ms
# [01:46:45] - [step:      34300] loss:  9.303e+01, time/iteration:  2.798e+01 ms
# [01:46:48] - [step:      34400] loss:  9.224e+01, time/iteration:  2.941e+01 ms
# [01:46:51] - [step:      34500] loss:  8.262e+01, time/iteration:  2.966e+01 ms
# [01:46:54] - [step:      34600] loss:  1.022e+02, time/iteration:  2.892e+01 ms
# [01:46:57] - [step:      34700] loss:  1.618e+02, time/iteration:  3.005e+01 ms
# [01:47:00] - [step:      34800] loss:  1.457e+02, time/iteration:  2.893e+01 ms
# [01:47:03] - [step:      34900] loss:  1.550e+02, time/iteration:  2.931e+01 ms
# [01:47:11] - [step:      35000] record validators time:  1.648e+00s
# [01:47:11] - [step:      35000] record monitor time:  2.221e-02s
# [01:47:11] - [step:      35000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:47:11] - [step:      35000] loss:  1.477e+02, time/iteration:  8.102e+01 ms
# [01:47:14] - [step:      35100] loss:  1.130e+02, time/iteration:  2.911e+01 ms
# [01:47:21] - [step:      35200] loss:  1.000e+02, time/iteration:  7.544e+01 ms
# [01:47:24] - [step:      35300] loss:  1.614e+02, time/iteration:  2.884e+01 ms
# [01:47:27] - [step:      35400] loss:  1.056e+02, time/iteration:  2.780e+01 ms
# [01:47:30] - [step:      35500] loss:  1.411e+02, time/iteration:  2.664e+01 ms
# [01:47:32] - [step:      35600] loss:  1.061e+02, time/iteration:  2.677e+01 ms
# [01:47:35] - [step:      35700] loss:  2.360e+02, time/iteration:  2.687e+01 ms
# [01:47:38] - [step:      35800] loss:  1.030e+02, time/iteration:  2.661e+01 ms
# [01:47:40] - [step:      35900] loss:  8.228e+01, time/iteration:  2.679e+01 ms
# [01:47:47] - [step:      36000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:47:47] - [step:      36000] loss:  1.726e+02, time/iteration:  6.258e+01 ms
# [01:47:49] - [step:      36100] loss:  1.297e+02, time/iteration:  2.687e+01 ms
# [01:47:52] - [step:      36200] loss:  1.061e+02, time/iteration:  2.685e+01 ms
# [01:47:55] - [step:      36300] loss:  2.261e+02, time/iteration:  2.693e+01 ms
# [01:47:57] - [step:      36400] loss:  9.736e+01, time/iteration:  2.719e+01 ms
# [01:48:00] - [step:      36500] loss:  1.008e+02, time/iteration:  2.716e+01 ms
# [01:48:03] - [step:      36600] loss:  1.038e+02, time/iteration:  2.701e+01 ms
# [01:48:05] - [step:      36700] loss:  1.910e+02, time/iteration:  2.707e+01 ms
# [01:48:08] - [step:      36800] loss:  8.634e+01, time/iteration:  2.697e+01 ms
# [01:48:12] - [step:      36900] loss:  9.560e+01, time/iteration:  3.527e+01 ms
# [01:48:18] - [step:      37000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:48:18] - [step:      37000] loss:  1.002e+02, time/iteration:  5.985e+01 ms
# [01:48:21] - [step:      37100] loss:  1.527e+02, time/iteration:  3.078e+01 ms
# [01:48:24] - [step:      37200] loss:  1.295e+02, time/iteration:  3.068e+01 ms
# [01:48:26] - [step:      37300] loss:  2.482e+02, time/iteration:  2.571e+01 ms
# [01:48:29] - [step:      37400] loss:  1.561e+02, time/iteration:  2.574e+01 ms
# [01:48:32] - [step:      37500] loss:  1.382e+02, time/iteration:  2.593e+01 ms
# [01:48:34] - [step:      37600] loss:  1.038e+02, time/iteration:  2.577e+01 ms
# [01:48:37] - [step:      37700] loss:  7.602e+01, time/iteration:  2.569e+01 ms
# [01:48:39] - [step:      37800] loss:  1.165e+02, time/iteration:  2.588e+01 ms
# [01:48:42] - [step:      37900] loss:  1.026e+02, time/iteration:  2.562e+01 ms
# [01:48:48] - [step:      38000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:48:48] - [step:      38000] loss:  1.360e+02, time/iteration:  6.123e+01 ms
# [01:48:51] - [step:      38100] loss:  9.300e+01, time/iteration:  2.642e+01 ms
# [01:48:53] - [step:      38200] loss:  1.007e+02, time/iteration:  2.663e+01 ms
# [01:48:56] - [step:      38300] loss:  1.824e+02, time/iteration:  2.650e+01 ms
# [01:48:59] - [step:      38400] loss:  8.177e+01, time/iteration:  2.652e+01 ms
# [01:49:01] - [step:      38500] loss:  1.210e+02, time/iteration:  2.664e+01 ms
# [01:49:04] - [step:      38600] loss:  2.923e+02, time/iteration:  2.658e+01 ms
# [01:49:07] - [step:      38700] loss:  7.944e+01, time/iteration:  3.526e+01 ms
# [01:49:10] - [step:      38800] loss:  1.850e+02, time/iteration:  2.660e+01 ms
# [01:49:13] - [step:      38900] loss:  7.553e+01, time/iteration:  2.668e+01 ms
# [01:49:19] - [step:      39000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:49:19] - [step:      39000] loss:  7.866e+01, time/iteration:  5.970e+01 ms
# [01:49:24] - [step:      39100] loss:  1.044e+02, time/iteration:  5.592e+01 ms
# [01:49:27] - [step:      39200] loss:  2.332e+02, time/iteration:  2.672e+01 ms
# [01:49:30] - [step:      39300] loss:  1.176e+02, time/iteration:  2.645e+01 ms
# [01:49:32] - [step:      39400] loss:  7.824e+01, time/iteration:  2.648e+01 ms
# [01:49:35] - [step:      39500] loss:  1.706e+02, time/iteration:  2.657e+01 ms
# [01:49:38] - [step:      39600] loss:  7.667e+01, time/iteration:  2.652e+01 ms
# [01:49:40] - [step:      39700] loss:  7.812e+01, time/iteration:  2.647e+01 ms
# [01:49:43] - [step:      39800] loss:  1.310e+02, time/iteration:  2.641e+01 ms
# [01:49:46] - [step:      39900] loss:  7.164e+01, time/iteration:  2.632e+01 ms
# [01:49:53] - [step:      40000] record validators time:  1.555e+00s
# [01:49:53] - [step:      40000] record monitor time:  2.203e-02s
# [01:49:53] - [step:      40000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:49:53] - [step:      40000] loss:  1.633e+02, time/iteration:  7.846e+01 ms
# [01:49:56] - [step:      40100] loss:  7.522e+01, time/iteration:  2.807e+01 ms
# [01:49:59] - [step:      40200] loss:  9.542e+01, time/iteration:  2.803e+01 ms
# [01:50:02] - [step:      40300] loss:  1.025e+02, time/iteration:  2.781e+01 ms
# [01:50:05] - [step:      40400] loss:  1.855e+02, time/iteration:  3.231e+01 ms
# [01:50:08] - [step:      40500] loss:  1.361e+02, time/iteration:  3.255e+01 ms
# [01:50:11] - [step:      40600] loss:  9.208e+01, time/iteration:  2.806e+01 ms
# [01:50:14] - [step:      40700] loss:  7.871e+01, time/iteration:  2.817e+01 ms
# [01:50:17] - [step:      40800] loss:  8.529e+01, time/iteration:  2.820e+01 ms
# [01:50:20] - [step:      40900] loss:  1.007e+02, time/iteration:  2.840e+01 ms
# [01:50:26] - [step:      41000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:50:26] - [step:      41000] loss:  1.060e+02, time/iteration:  6.704e+01 ms
# [01:50:29] - [step:      41100] loss:  2.258e+02, time/iteration:  3.174e+01 ms
# [01:50:32] - [step:      41200] loss:  1.017e+02, time/iteration:  2.757e+01 ms
# [01:50:35] - [step:      41300] loss:  8.887e+01, time/iteration:  2.744e+01 ms
# [01:50:38] - [step:      41400] loss:  8.180e+01, time/iteration:  2.743e+01 ms
# [01:50:40] - [step:      41500] loss:  1.676e+02, time/iteration:  2.739e+01 ms
# [01:50:43] - [step:      41600] loss:  1.142e+02, time/iteration:  2.741e+01 ms
# [01:50:46] - [step:      41700] loss:  1.488e+02, time/iteration:  2.728e+01 ms
# [01:50:49] - [step:      41800] loss:  7.362e+01, time/iteration:  2.749e+01 ms
# [01:50:51] - [step:      41900] loss:  8.883e+01, time/iteration:  2.735e+01 ms
# [01:50:58] - [step:      42000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:50:58] - [step:      42000] loss:  7.245e+01, time/iteration:  6.394e+01 ms
# [01:51:00] - [step:      42100] loss:  1.383e+02, time/iteration:  2.693e+01 ms
# [01:51:04] - [step:      42200] loss:  6.735e+01, time/iteration:  3.500e+01 ms
# [01:51:07] - [step:      42300] loss:  1.010e+02, time/iteration:  2.730e+01 ms
# [01:51:09] - [step:      42400] loss:  1.216e+02, time/iteration:  2.699e+01 ms
# [01:51:12] - [step:      42500] loss:  1.071e+02, time/iteration:  2.689e+01 ms
# [01:51:15] - [step:      42600] loss:  8.703e+01, time/iteration:  2.692e+01 ms
# [01:51:17] - [step:      42700] loss:  6.901e+01, time/iteration:  2.701e+01 ms
# [01:51:20] - [step:      42800] loss:  1.353e+02, time/iteration:  2.717e+01 ms
# [01:51:23] - [step:      42900] loss:  9.236e+01, time/iteration:  2.714e+01 ms
# [01:51:32] - [step:      43000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:51:32] - [step:      43000] loss:  1.070e+02, time/iteration:  8.931e+01 ms
# [01:51:34] - [step:      43100] loss:  1.811e+02, time/iteration:  2.549e+01 ms
# [01:51:37] - [step:      43200] loss:  7.514e+01, time/iteration:  2.566e+01 ms
# [01:51:40] - [step:      43300] loss:  2.259e+02, time/iteration:  2.559e+01 ms
# [01:51:42] - [step:      43400] loss:  1.417e+02, time/iteration:  2.558e+01 ms
# [01:51:45] - [step:      43500] loss:  9.237e+01, time/iteration:  2.557e+01 ms
# [01:51:47] - [step:      43600] loss:  1.010e+02, time/iteration:  2.581e+01 ms
# [01:51:50] - [step:      43700] loss:  1.082e+02, time/iteration:  2.546e+01 ms
# [01:51:52] - [step:      43800] loss:  1.563e+02, time/iteration:  2.538e+01 ms
# [01:51:55] - [step:      43900] loss:  1.235e+02, time/iteration:  2.563e+01 ms
# [01:52:02] - [step:      44000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:52:02] - [step:      44000] loss:  1.808e+02, time/iteration:  7.015e+01 ms
# [01:52:04] - [step:      44100] loss:  6.450e+01, time/iteration:  2.541e+01 ms
# [01:52:07] - [step:      44200] loss:  6.882e+01, time/iteration:  2.548e+01 ms
# [01:52:09] - [step:      44300] loss:  1.559e+02, time/iteration:  2.519e+01 ms
# [01:52:12] - [step:      44400] loss:  1.296e+02, time/iteration:  2.536e+01 ms
# [01:52:15] - [step:      44500] loss:  6.848e+01, time/iteration:  2.522e+01 ms
# [01:52:17] - [step:      44600] loss:  6.203e+01, time/iteration:  2.539e+01 ms
# [01:52:20] - [step:      44700] loss:  6.845e+01, time/iteration:  2.531e+01 ms
# [01:52:22] - [step:      44800] loss:  7.203e+01, time/iteration:  2.524e+01 ms
# [01:52:25] - [step:      44900] loss:  7.843e+01, time/iteration:  3.025e+01 ms
# [01:52:33] - [step:      45000] record validators time:  1.587e+00s
# [01:52:33] - [step:      45000] record monitor time:  2.192e-02s
# [01:52:33] - [step:      45000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:52:33] - [step:      45000] loss:  6.337e+01, time/iteration:  7.927e+01 ms
# [01:52:35] - [step:      45100] loss:  8.562e+01, time/iteration:  2.403e+01 ms
# [01:52:38] - [step:      45200] loss:  7.248e+01, time/iteration:  2.412e+01 ms
# [01:52:40] - [step:      45300] loss:  8.428e+01, time/iteration:  2.403e+01 ms
# [01:52:43] - [step:      45400] loss:  1.288e+02, time/iteration:  2.412e+01 ms
# [01:52:45] - [step:      45500] loss:  7.941e+01, time/iteration:  2.412e+01 ms
# [01:52:48] - [step:      45600] loss:  6.523e+01, time/iteration:  2.390e+01 ms
# [01:52:51] - [step:      45700] loss:  1.051e+02, time/iteration:  3.230e+01 ms
# [01:52:53] - [step:      45800] loss:  6.179e+01, time/iteration:  2.465e+01 ms
# [01:52:56] - [step:      45900] loss:  1.276e+02, time/iteration:  2.419e+01 ms
# [01:53:02] - [step:      46000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:53:02] - [step:      46000] loss:  8.659e+01, time/iteration:  6.023e+01 ms
# [01:53:04] - [step:      46100] loss:  7.515e+01, time/iteration:  2.407e+01 ms
# [01:53:06] - [step:      46200] loss:  8.572e+01, time/iteration:  2.381e+01 ms
# [01:53:09] - [step:      46300] loss:  8.161e+01, time/iteration:  2.405e+01 ms
# [01:53:11] - [step:      46400] loss:  2.099e+02, time/iteration:  2.399e+01 ms
# [01:53:14] - [step:      46500] loss:  7.428e+01, time/iteration:  2.404e+01 ms
# [01:53:16] - [step:      46600] loss:  6.179e+01, time/iteration:  2.404e+01 ms
# [01:53:18] - [step:      46700] loss:  5.953e+01, time/iteration:  2.390e+01 ms
# [01:53:21] - [step:      46800] loss:  1.850e+02, time/iteration:  2.398e+01 ms
# [01:53:26] - [step:      46900] loss:  8.097e+01, time/iteration:  5.282e+01 ms
# [01:53:32] - [step:      47000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:53:32] - [step:      47000] loss:  7.622e+01, time/iteration:  5.864e+01 ms
# [01:53:34] - [step:      47100] loss:  1.105e+02, time/iteration:  2.456e+01 ms
# [01:53:37] - [step:      47200] loss:  7.003e+01, time/iteration:  2.443e+01 ms
# [01:53:39] - [step:      47300] loss:  6.178e+01, time/iteration:  2.435e+01 ms
# [01:53:42] - [step:      47400] loss:  6.598e+01, time/iteration:  2.453e+01 ms
# [01:53:45] - [step:      47500] loss:  6.807e+01, time/iteration:  3.304e+01 ms
# [01:53:48] - [step:      47600] loss:  6.447e+01, time/iteration:  2.468e+01 ms
# [01:53:50] - [step:      47700] loss:  6.130e+01, time/iteration:  2.452e+01 ms
# [01:53:52] - [step:      47800] loss:  2.237e+02, time/iteration:  2.462e+01 ms
# [01:53:55] - [step:      47900] loss:  7.179e+01, time/iteration:  2.437e+01 ms
# [01:54:01] - [step:      48000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [01:54:01] - [step:      48000] loss:  7.006e+01, time/iteration:  6.044e+01 ms
# [01:54:03] - [step:      48100] loss:  6.147e+01, time/iteration:  2.422e+01 ms
# ...
# [12:40:46] - [step:     856300] loss:  9.761e+00, time/iteration:  4.817e+01 ms
# [12:40:51] - [step:     856400] loss:  9.667e+00, time/iteration:  4.868e+01 ms
# [12:40:56] - [step:     856500] loss:  1.183e+01, time/iteration:  4.820e+01 ms
# [12:41:01] - [step:     856600] loss:  9.159e+00, time/iteration:  4.844e+01 ms
# [12:41:06] - [step:     856700] loss:  1.038e+01, time/iteration:  4.833e+01 ms
# [12:41:11] - [step:     856800] loss:  1.073e+01, time/iteration:  5.015e+01 ms
# [12:41:16] - [step:     856900] loss:  1.219e+01, time/iteration:  5.196e+01 ms
# [12:41:25] - [step:     857000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [12:41:25] - [step:     857000] loss:  1.010e+01, time/iteration:  8.878e+01 ms
# [12:41:30] - [step:     857100] loss:  9.909e+00, time/iteration:  5.602e+01 ms
# [12:41:35] - [step:     857200] loss:  9.720e+00, time/iteration:  5.014e+01 ms
# [12:41:41] - [step:     857300] loss:  1.040e+01, time/iteration:  5.243e+01 ms
# [12:41:48] - [step:     857400] loss:  1.066e+01, time/iteration:  7.155e+01 ms
# [12:41:53] - [step:     857500] loss:  1.173e+01, time/iteration:  5.517e+01 ms
# [12:41:58] - [step:     857600] loss:  1.098e+01, time/iteration:  4.917e+01 ms
# [12:42:03] - [step:     857700] loss:  1.026e+01, time/iteration:  5.190e+01 ms
# [12:42:08] - [step:     857800] loss:  8.637e+00, time/iteration:  5.126e+01 ms
# [12:42:14] - [step:     857900] loss:  1.045e+01, time/iteration:  5.129e+01 ms
# [12:42:22] - [step:     858000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [12:42:22] - [step:     858000] loss:  1.016e+01, time/iteration:  8.916e+01 ms
# [12:42:28] - [step:     858100] loss:  1.022e+01, time/iteration:  5.254e+01 ms
# [12:42:33] - [step:     858200] loss:  9.881e+00, time/iteration:  5.036e+01 ms
# [12:42:38] - [step:     858300] loss:  1.090e+01, time/iteration:  5.101e+01 ms
# [12:42:43] - [step:     858400] loss:  1.022e+01, time/iteration:  5.055e+01 ms
# [12:42:48] - [step:     858500] loss:  1.234e+01, time/iteration:  5.258e+01 ms
# [12:42:54] - [step:     858600] loss:  1.085e+01, time/iteration:  5.571e+01 ms
# [12:42:59] - [step:     858700] loss:  1.137e+01, time/iteration:  5.490e+01 ms
# [12:43:05] - [step:     858800] loss:  1.123e+01, time/iteration:  5.444e+01 ms
# [12:43:10] - [step:     858900] loss:  1.185e+01, time/iteration:  5.444e+01 ms
# [12:43:20] - [step:     859000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [12:43:20] - [step:     859000] loss:  1.047e+01, time/iteration:  1.003e+02 ms
# [12:43:26] - [step:     859100] loss:  1.031e+01, time/iteration:  6.085e+01 ms
# [12:43:33] - [step:     859200] loss:  9.880e+00, time/iteration:  6.651e+01 ms
# [12:43:40] - [step:     859300] loss:  1.074e+01, time/iteration:  7.485e+01 ms
# [12:43:48] - [step:     859400] loss:  1.045e+01, time/iteration:  7.673e+01 ms
# [12:43:53] - [step:     859500] loss:  1.090e+01, time/iteration:  5.244e+01 ms
# [12:43:59] - [step:     859600] loss:  9.401e+00, time/iteration:  5.587e+01 ms
# [12:44:04] - [step:     859700] loss:  1.123e+01, time/iteration:  5.457e+01 ms
# [12:44:10] - [step:     859800] loss:  1.194e+01, time/iteration:  5.259e+01 ms
# [12:44:15] - [step:     859900] loss:  1.164e+01, time/iteration:  5.599e+01 ms
# [12:44:26] - [step:     860000] record validators time:  1.646e+00s
# [12:44:26] - [step:     860000] record monitor time:  2.353e-02s
# [12:44:26] - [step:     860000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [12:44:26] - [step:     860000] loss:  1.064e+01, time/iteration:  1.116e+02 ms
# [12:44:32] - [step:     860100] loss:  1.022e+01, time/iteration:  5.518e+01 ms
# [12:44:37] - [step:     860200] loss:  1.092e+01, time/iteration:  5.245e+01 ms
# [12:44:42] - [step:     860300] loss:  1.205e+01, time/iteration:  5.227e+01 ms
# [12:44:48] - [step:     860400] loss:  1.162e+01, time/iteration:  5.404e+01 ms
# [12:44:53] - [step:     860500] loss:  1.082e+01, time/iteration:  5.354e+01 ms
# [12:44:58] - [step:     860600] loss:  9.017e+00, time/iteration:  5.342e+01 ms
# [12:45:04] - [step:     860700] loss:  1.052e+01, time/iteration:  5.267e+01 ms
# [12:45:09] - [step:     860800] loss:  1.090e+01, time/iteration:  5.442e+01 ms
# [12:45:15] - [step:     860900] loss:  1.169e+01, time/iteration:  5.453e+01 ms
# [12:45:26] - [step:     861000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [12:45:26] - [step:     861000] loss:  1.017e+01, time/iteration:  1.142e+02 ms
# [12:45:31] - [step:     861100] loss:  9.046e+00, time/iteration:  5.333e+01 ms
# [12:45:37] - [step:     861200] loss:  9.564e+00, time/iteration:  5.490e+01 ms
# [12:45:44] - [step:     861300] loss:  1.110e+01, time/iteration:  7.067e+01 ms
# [12:45:49] - [step:     861400] loss:  1.029e+01, time/iteration:  5.148e+01 ms
# [12:45:54] - [step:     861500] loss:  1.066e+01, time/iteration:  5.027e+01 ms
# [12:45:59] - [step:     861600] loss:  1.066e+01, time/iteration:  5.059e+01 ms
# [12:46:04] - [step:     861700] loss:  1.061e+01, time/iteration:  5.048e+01 ms
# [12:46:09] - [step:     861800] loss:  9.312e+00, time/iteration:  5.092e+01 ms
# [12:46:14] - [step:     861900] loss:  9.280e+00, time/iteration:  5.082e+01 ms
# [12:46:23] - [step:     862000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [12:46:23] - [step:     862000] loss:  1.114e+01, time/iteration:  8.712e+01 ms
# [12:46:28] - [step:     862100] loss:  1.130e+01, time/iteration:  5.049e+01 ms
# [12:46:33] - [step:     862200] loss:  1.061e+01, time/iteration:  5.017e+01 ms
# [12:46:38] - [step:     862300] loss:  1.162e+01, time/iteration:  5.037e+01 ms
# [12:46:43] - [step:     862400] loss:  1.082e+01, time/iteration:  4.987e+01 ms
# [12:46:48] - [step:     862500] loss:  1.105e+01, time/iteration:  4.996e+01 ms
# [12:46:53] - [step:     862600] loss:  9.545e+00, time/iteration:  5.062e+01 ms
# [12:47:00] - [step:     862700] loss:  1.154e+01, time/iteration:  6.303e+01 ms
# [12:47:05] - [step:     862800] loss:  9.344e+00, time/iteration:  5.049e+01 ms
# [12:47:10] - [step:     862900] loss:  1.059e+01, time/iteration:  5.027e+01 ms
# [12:47:19] - [step:     863000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [12:47:19] - [step:     863000] loss:  1.040e+01, time/iteration:  9.059e+01 ms
# [12:47:24] - [step:     863100] loss:  1.105e+01, time/iteration:  5.033e+01 ms
# [12:47:31] - [step:     863200] loss:  9.116e+00, time/iteration:  7.410e+01 ms
# [12:47:38] - [step:     863300] loss:  1.023e+01, time/iteration:  7.186e+01 ms
# [12:47:43] - [step:     863400] loss:  1.063e+01, time/iteration:  5.038e+01 ms
# [12:47:48] - [step:     863500] loss:  1.154e+01, time/iteration:  5.024e+01 ms
# [12:47:53] - [step:     863600] loss:  9.043e+00, time/iteration:  4.998e+01 ms
# [12:47:58] - [step:     863700] loss:  1.270e+01, time/iteration:  5.020e+01 ms
# [12:48:03] - [step:     863800] loss:  9.558e+00, time/iteration:  5.017e+01 ms
# [12:48:08] - [step:     863900] loss:  1.025e+01, time/iteration:  5.050e+01 ms
# [12:48:17] - [step:     864000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [12:48:17] - [step:     864000] loss:  9.740e+00, time/iteration:  8.616e+01 ms
# [12:48:22] - [step:     864100] loss:  9.845e+00, time/iteration:  5.066e+01 ms
# [12:48:27] - [step:     864200] loss:  1.044e+01, time/iteration:  5.107e+01 ms
# [12:48:32] - [step:     864300] loss:  1.082e+01, time/iteration:  5.102e+01 ms
# [12:48:37] - [step:     864400] loss:  1.030e+01, time/iteration:  5.103e+01 ms
# [12:48:44] - [step:     864500] loss:  1.247e+01, time/iteration:  6.366e+01 ms
# [12:48:49] - [step:     864600] loss:  1.009e+01, time/iteration:  5.112e+01 ms
# [12:48:54] - [step:     864700] loss:  1.034e+01, time/iteration:  5.108e+01 ms
# [12:48:59] - [step:     864800] loss:  9.721e+00, time/iteration:  5.118e+01 ms
# [12:49:04] - [step:     864900] loss:  1.108e+01, time/iteration:  5.076e+01 ms
# [12:49:15] - [step:     865000] record validators time:  2.092e+00s
# [12:49:15] - [step:     865000] record monitor time:  2.395e-02s
# [12:49:15] - [step:     865000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [12:49:15] - [step:     865000] loss:  1.092e+01, time/iteration:  1.078e+02 ms
# [12:49:20] - [step:     865100] loss:  1.040e+01, time/iteration:  5.057e+01 ms
# [12:49:27] - [step:     865200] loss:  1.017e+01, time/iteration:  6.586e+01 ms
# [12:49:32] - [step:     865300] loss:  1.133e+01, time/iteration:  5.028e+01 ms
# [12:49:37] - [step:     865400] loss:  9.583e+00, time/iteration:  5.070e+01 ms
# [12:49:42] - [step:     865500] loss:  1.061e+01, time/iteration:  5.062e+01 ms
# [12:49:47] - [step:     865600] loss:  9.751e+00, time/iteration:  5.032e+01 ms
# [12:49:52] - [step:     865700] loss:  9.670e+00, time/iteration:  5.085e+01 ms
# [12:49:57] - [step:     865800] loss:  9.895e+00, time/iteration:  5.101e+01 ms
# [12:50:02] - [step:     865900] loss:  1.077e+01, time/iteration:  5.109e+01 ms
# [12:50:11] - [step:     866000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [12:50:11] - [step:     866000] loss:  1.022e+01, time/iteration:  8.735e+01 ms
# [12:50:16] - [step:     866100] loss:  9.580e+00, time/iteration:  5.106e+01 ms
# [12:50:22] - [step:     866200] loss:  1.064e+01, time/iteration:  6.271e+01 ms
# [12:50:27] - [step:     866300] loss:  1.088e+01, time/iteration:  5.172e+01 ms
# [12:50:33] - [step:     866400] loss:  9.866e+00, time/iteration:  5.055e+01 ms
# [12:50:38] - [step:     866500] loss:  1.040e+01, time/iteration:  5.078e+01 ms
# [12:50:43] - [step:     866600] loss:  1.020e+01, time/iteration:  5.117e+01 ms
# [12:50:48] - [step:     866700] loss:  9.823e+00, time/iteration:  5.144e+01 ms
# [12:50:53] - [step:     866800] loss:  1.061e+01, time/iteration:  5.167e+01 ms
# [12:50:58] - [step:     866900] loss:  9.545e+00, time/iteration:  5.092e+01 ms
# [12:51:09] - [step:     867000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [12:51:09] - [step:     867000] loss:  1.100e+01, time/iteration:  1.076e+02 ms
# [12:51:14] - [step:     867100] loss:  1.198e+01, time/iteration:  5.456e+01 ms
# [12:51:24] - [step:     867200] loss:  1.007e+01, time/iteration:  1.012e+02 ms
# [12:51:30] - [step:     867300] loss:  1.076e+01, time/iteration:  5.266e+01 ms
# [12:51:35] - [step:     867400] loss:  1.012e+01, time/iteration:  5.377e+01 ms
# [12:51:41] - [step:     867500] loss:  1.058e+01, time/iteration:  5.904e+01 ms
# [12:51:46] - [step:     867600] loss:  1.026e+01, time/iteration:  5.286e+01 ms
# [12:51:52] - [step:     867700] loss:  9.540e+00, time/iteration:  5.265e+01 ms
# [12:51:57] - [step:     867800] loss:  1.243e+01, time/iteration:  5.239e+01 ms
# [12:52:02] - [step:     867900] loss:  1.045e+01, time/iteration:  5.137e+01 ms
# [12:52:12] - [step:     868000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [12:52:12] - [step:     868000] loss:  9.782e+00, time/iteration:  1.031e+02 ms
# [12:52:18] - [step:     868100] loss:  9.798e+00, time/iteration:  5.284e+01 ms
# [12:52:23] - [step:     868200] loss:  1.009e+01, time/iteration:  5.209e+01 ms
# [12:52:28] - [step:     868300] loss:  1.007e+01, time/iteration:  5.197e+01 ms
# [12:52:33] - [step:     868400] loss:  1.058e+01, time/iteration:  5.268e+01 ms
# [12:52:38] - [step:     868500] loss:  9.360e+00, time/iteration:  5.272e+01 ms
# [12:52:44] - [step:     868600] loss:  8.788e+00, time/iteration:  5.295e+01 ms
# [12:52:49] - [step:     868700] loss:  1.076e+01, time/iteration:  5.454e+01 ms
# [12:52:54] - [step:     868800] loss:  1.051e+01, time/iteration:  5.209e+01 ms
# [12:53:00] - [step:     868900] loss:  1.080e+01, time/iteration:  5.234e+01 ms
# [12:53:09] - [step:     869000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [12:53:09] - [step:     869000] loss:  1.139e+01, time/iteration:  9.299e+01 ms
# [12:53:16] - [step:     869100] loss:  1.146e+01, time/iteration:  7.423e+01 ms
# [12:53:22] - [step:     869200] loss:  1.022e+01, time/iteration:  5.270e+01 ms
# [12:53:27] - [step:     869300] loss:  9.265e+00, time/iteration:  5.230e+01 ms
# [12:53:32] - [step:     869400] loss:  1.057e+01, time/iteration:  5.451e+01 ms
# [12:53:38] - [step:     869500] loss:  9.995e+00, time/iteration:  5.318e+01 ms
# [12:53:43] - [step:     869600] loss:  1.076e+01, time/iteration:  5.570e+01 ms
# [12:53:49] - [step:     869700] loss:  1.091e+01, time/iteration:  6.062e+01 ms
# [12:53:55] - [step:     869800] loss:  8.552e+00, time/iteration:  6.150e+01 ms
# [12:54:01] - [step:     869900] loss:  1.027e+01, time/iteration:  5.319e+01 ms
# [12:54:11] - [step:     870000] record validators time:  1.666e+00s
# [12:54:11] - [step:     870000] record monitor time:  2.493e-02s
# [12:54:11] - [step:     870000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [12:54:11] - [step:     870000] loss:  1.190e+01, time/iteration:  1.074e+02 ms
# [12:54:17] - [step:     870100] loss:  1.095e+01, time/iteration:  5.110e+01 ms
# [12:54:22] - [step:     870200] loss:  1.128e+01, time/iteration:  5.229e+01 ms
# [12:54:27] - [step:     870300] loss:  1.010e+01, time/iteration:  5.086e+01 ms
# [12:54:32] - [step:     870400] loss:  9.431e+00, time/iteration:  5.123e+01 ms
# [12:54:37] - [step:     870500] loss:  1.030e+01, time/iteration:  5.214e+01 ms
# [12:54:43] - [step:     870600] loss:  9.540e+00, time/iteration:  5.429e+01 ms
# [12:54:48] - [step:     870700] loss:  1.050e+01, time/iteration:  5.145e+01 ms
# [12:54:53] - [step:     870800] loss:  9.948e+00, time/iteration:  5.305e+01 ms
# [12:54:58] - [step:     870900] loss:  1.086e+01, time/iteration:  5.195e+01 ms
# [12:55:08] - [step:     871000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [12:55:08] - [step:     871000] loss:  1.017e+01, time/iteration:  9.361e+01 ms
# [12:55:18] - [step:     871100] loss:  9.623e+00, time/iteration:  1.043e+02 ms
# [12:55:23] - [step:     871200] loss:  1.126e+01, time/iteration:  5.307e+01 ms
# [12:55:29] - [step:     871300] loss:  1.057e+01, time/iteration:  5.260e+01 ms
# [12:55:34] - [step:     871400] loss:  9.326e+00, time/iteration:  5.243e+01 ms
# [12:55:41] - [step:     871500] loss:  1.145e+01, time/iteration:  6.609e+01 ms
# [12:55:46] - [step:     871600] loss:  1.082e+01, time/iteration:  5.682e+01 ms
# [12:55:52] - [step:     871700] loss:  1.281e+01, time/iteration:  5.301e+01 ms
# [12:55:57] - [step:     871800] loss:  9.329e+00, time/iteration:  5.472e+01 ms
# [12:56:02] - [step:     871900] loss:  9.906e+00, time/iteration:  5.310e+01 ms
# [12:56:12] - [step:     872000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [12:56:12] - [step:     872000] loss:  1.269e+01, time/iteration:  9.372e+01 ms
# [12:56:17] - [step:     872100] loss:  1.030e+01, time/iteration:  5.151e+01 ms
# [12:56:23] - [step:     872200] loss:  1.072e+01, time/iteration:  5.766e+01 ms
# [12:56:28] - [step:     872300] loss:  1.017e+01, time/iteration:  5.640e+01 ms
# [12:56:34] - [step:     872400] loss:  1.024e+01, time/iteration:  5.282e+01 ms
# [12:56:39] - [step:     872500] loss:  1.072e+01, time/iteration:  5.344e+01 ms
# [12:56:44] - [step:     872600] loss:  1.099e+01, time/iteration:  5.535e+01 ms
# [12:56:50] - [step:     872700] loss:  1.028e+01, time/iteration:  5.172e+01 ms
# [12:56:55] - [step:     872800] loss:  1.093e+01, time/iteration:  5.443e+01 ms
# [12:57:00] - [step:     872900] loss:  9.593e+00, time/iteration:  5.047e+01 ms
# [12:57:11] - [step:     873000] saved checkpoint to outputs/fhn3Ppred/initial_conditions
# [12:57:11] - [step:     873000] loss:  1.019e+01, time/iteration:  1.111e+02 ms
# [12:57:16] - [step:     873100] loss:  1.008e+01, time/iteration:  5.307e+01 ms
# [12:57:22] - [step:     873200] loss:  1.072e+01, time/iteration:  5.905e+01 ms
# [12:57:29] - [step:     873300] loss:  1.106e+01, time/iteration:  6.268e+01 ms
# [12:57:34] - [step:     873400] loss:  1.343e+01, time/iteration:  5.433e+01 ms
# [12:57:39] - [step:     873500] loss:  1.015e+01, time/iteration:  5.334e+01 ms
# [12:57:45] - [step:     873600] loss:  1.081e+01, time/iteration:  5.350e+01 ms
# [12:57:50] - [step:     873700] loss:  9.485e+00, time/iteration:  5.306e+01 ms
# [12:57:55] - [step:     873800] loss:  1.185e+01, time/iteration:  5.172e+01 ms
